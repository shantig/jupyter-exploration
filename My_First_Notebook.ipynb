# %% [markdown]
# <a href="https://colab.research.google.com/github/shantig/jupyter-exploration/blob/main/My_First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My first markdown cell in Jupyter. 👶

# %%
# Generated by ChatGPT 5 and modified by Gemini.

from PIL import Image, ImageDraw, ImageOps
import math
import requests
from io import BytesIO

# ---------- ASCII conversion ----------
def image_to_ascii(img, width=120, charset=" .:-=+*#%@", invert=False):
    # Composite to RGB & grayscale
    if img.mode in ("RGBA", "LA"):
        bg = Image.new("RGB", img.size, "white")
        bg.paste(img, mask=img.split()[-1])
        img = bg
    else:
        img = img.convert("RGB")
    img = ImageOps.grayscale(img)

    # Aspect correction for monospace characters (~2:1 height:width)
    w, h = img.size
    aspect_ratio = h / w
    char_aspect = 0.5
    new_h = max(1, int(aspect_ratio * width * char_aspect))
    img = img.resize((width, new_h), Image.Resampling.LANCZOS)

    if invert:
        charset = charset[::-1]
    scale = (len(charset) - 1) / 255.0
    pixels = img.getdata()
    ascii_str = "".join(charset[int(p * scale)] for p in pixels)
    return "\n".join(ascii_str[i:i+width] for i in range(0, len(ascii_str), width))

# ---------- Load image from URL and convert to ASCII ----------
image_url = "https://www.hccs.edu/media/hcc-redesign/style-assets/images/img/hcc-logo-black.png"

try:
    response = requests.get(image_url)
    response.raise_for_status()  # Raise an exception for bad status codes
    img = Image.open(BytesIO(response.content))

    # Convert to ASCII and print
    print(image_to_ascii(img, width=140))

except requests.exceptions.RequestException as e:
    print(f"Error downloading image: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
